# %% [markdown]
# IF Statements

# %%
#Write a Python program that checks if a number is positive.

num= int(input('enter the number:'))
if(num>0):
  print(f"the given number {num} is positive")
# Out:
# enter the number:-1

# %%
#Write a Python program that checks if a given string is empty.
a= input()
if len(a)==0:
  print("the given string is empty")
# Out:
# the given string is empty

# %%
#Write a Python program that determines if a number is positive, negative, or zero using only if statements and no elif or else.
a=int(input())
if(a>0):
  print("the number is positive")
if(a==0):
  print("the number is zero")
if(a<0):
    print('the number is negative')
# Out:
# -3
# the number is negative

# %%
#Write a Python program that checks if a number is a multiple of both 3 and 5.
num=int(input())
if num%3==0 and num%5==0:
  print(f"{num} is divible by both 3 and 5")
# Out:
# 15
# 15 is divible by both 3 and 5

# %%
#Write a Python program that determines if a given number is a perfect square.
num=int(input())
if (num<0):
  print('zero cannot be square root')
if(num>0):
  root = int(num**0.5)
  print(root *root==num)
# Out:
# 144
# True

# %%
#Write a Python program that checks if a number is divisible by both 2 and 3.
num=int(input())
if(num%2==0 and num%3==0):
  print(f'{num} is divisible by both 2 and 3')
# Out:
# 6
# 6 is divisible by both 2 and 3

# %%
#Write a Python program that determines if a number is a perfect cube.
num = int(input("Enter a number: "))

# Calculate the cube root
cube_root = round(num ** (1/3))

# Check if the number is a perfect cube
if cube_root ** 3 == num:
    print(f"The number {num} is a perfect cube.")
# Out:
# Enter a number: 8
# The number 8 is a perfect cube.

# %%
#Write a Python program that checks if a given number is a multiple of 4.

num= int(input())
if num%4==0:
  print(f'{num} is multiple of 4')
# Out:
# 20
# 20 is multiple of 4

# %% [markdown]
# IF Else Statement

# %%
#Write a Python program that checks if a given year is a leap year.
year=int(input())
# Divisible by 4 AND (NOT divisible by 100 OR divisible by 400)
if year%4==0:
  if year%100==0:
    print(year%400==0)
  else:
    print('True')
else:
  print('false')
# Out:
# 2024
# True

# %%
#Write a Python program that checks if a given character is a vowel or a consonant.

a=input()
vowels=['a','e','i','o','u']
if a in vowels:
  print(' its a vowel')
else:
  print('its a consonant')
# Out:
# r
# its a consonant

# %%
#Write a Python program that checks if a given year is a century year (ending in '00').

year= int(input())

if year%100==0:
  print(f'{year} is a centuary year')
else:
  print('its not a centuary year')
# Out:
# 2100
# 2100 is a centuary year

# %%
#Write a Python program that calculates and prints the absolute value of a given number.
num = int(input("Enter a number: "))

absolute_value = abs(num)
print(f"The absolute value of {num} is {absolute_value}.")
# Out:
# Enter a number: 7
# 7 is a prime number

# %%
#Write a Python program that checks if a person is eligible to vote based on their age.
age=int(input())
if age>=18:
  print('you are eligible to vote')
else:
  print('you are not eligible')
# Out:
# 5
# you are not eligible

# %%
#Write a Python program that checks if a number is positive or non-positive (including  zero).
num=int(input())

if num >0:
  print('the number is positive')
else:
  print('the number is either zero or negative')
# Out:
# 0
# the number is either zero or negative

# %%
#Write a Python program that compares two numbers and prints the largest one.
a=int(input())
b=int(input())

if a<b and b>a:
  print(f'{b} is the largest')
else:
  print(f'{a} is the largest ')
# Out:
# 5
# 6
# 6 is the largest

# %%
#Write a Python program that checks if a given character is a letter or not.
a=input()

if a.isalpha():
  print('the given character is letter')
else:
  print('the given character is not letter')
# Out:
# 5
# the given character is not letter

# %%
#Write a Python program that finds and prints the smallest of three numbers without using inbuilt methods.
a=int(input())
b=int(input())
c=int(input())

if a<b and b>a and c>a:
  print(f'{a} is the smallest')
elif a>b and b<a and c>b:
  print(f'{b} is the smallest')
else:
  print(f'{c} is the smallest')
# Out:
# 5
# 4
# 3
# 3 is the smallest

# %%
#Write a Python program to check if a given string is a palindrome.

char=input()

if char== char[::-1]:
  print(f"{char} is a palindrome")
else:
  print(f"{char} is not a palindrome")
# Out:
# madam
# madam is a palindrome

# %%
#. Write a Python program that finds and prints the largest of four numbers
a=int(input())
b=int(input())
c=int(input())
d=int(input())

if a>b and a>c and a>d:
  print(f'{a} is the largest')
elif b>a and b>c and b>d:
  print(f'{b} is the largest')
elif c>a and c>b and c>d:
  print(f'{c} is the largest')
else:
  print(f'{d} is the largest')
# Out:
# 1
# 2
# 3
# 5
# 5 is the largest

# %%
#Write a Python program that takes two numbers as input and determines the sign of their difference.

a=int(input("Enter the first number: "))
b=int(input("Enter the second number: "))
c = a - b

if c > 0:
  print(f'The difference ({c}) is positive.')
elif c < 0:
  print(f'The difference ({c}) is negative.')
else:
  print(f'The difference ({c}) is zero.')
# Out:
# Enter the first number: 5
# Enter the second number: 6
# The difference (-1) is negative.

# %%
#Write a Python program that checks if a given year is a leap year using an alternative method.
year = int(input("Enter a year: "))

# A year is a leap year if it is divisible by 4, unless it is divisible by 100 but not by 400.
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f'{year} is a leap year.')
else:
    print(f'{year} is not a leap year.')
# Out:
# Enter a year: 2024
# 2024 is a leap year.

# %%
#Write a Python program that checks if a number is a multiple of 7 or not

num=int(input())

if num%7==0:
  print('the number is divisible by 7')
else:
  print('the number is not divisible by 7')
# Out:
# 49
# the number is divisible by 7

# %%
#Write a Python program that calculates and prints the absolute value of a given number.
num=int(input())

if num<0:
  print(-1 *num)
else:
  print(num)
# Out:
# -49
# 49
