# %% [markdown]
# Given a string, slice it to extract the first 3 characters.

# %%
n=input('enter the input to slice the first 3 character : ')
print(n[:3])
# Out:
# enter the input to slice the first 3 character : murali
# mur

# %% [markdown]
# Reversing a List using slicing

# %%
l=[1,2,3,4,5,6]
print(l[::-1])
# Out:
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# Slicing a Tuple

# %%
n=(10,11,12,13,14)
print(n[:2])
# Out:
# (10, 11)

# %% [markdown]
# Modify a List Using Slicing

# %%
n= [100,200,300,400]
n[1]=500
print(n)
# Out:
# [100, 500, 300, 400]

# %% [markdown]
# Extract Even-Indexed Characters from a String

# %%
text = "Python"
result = text[::2]
print(result)  # Output: Pto
# Out:
# Pto

# %% [markdown]
# Slicing a List of Lists

# %%
I= [1 ,[2,3,4],5,6]
I[1][1:]
# Out:
# [3, 4]

# %% [markdown]
# Slicing a String in Reverse

# %%
a='Vcube'
a[::-1]
# Out:
# 'ebucV'

# %% [markdown]
# Slicing with a Step of 3

# %%
a='Python'
print(a[::3])
# Out:
# Ph

# %% [markdown]
# Reversing a List of Strings.

# %%
a=['vcube','python','java']
a=[x[::-1] for x in a ]
print(a)
# Out:
# ['ebucv', 'nohtyp', 'avaj']

# %%
a=['vcube','python','java']
b=['vcube','python','java']
a[2]=b
print(a)
# Out:
# ['vcube', 'python', ['vcube', 'python', 'java']]
