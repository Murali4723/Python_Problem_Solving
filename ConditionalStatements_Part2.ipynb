# %%
#Write a Python program that converts a temperature in Celsius to Fahrenheit or vice versa based on user input.

def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

def fahrenheit_to_celsius(fahrenheit):
    return (fahrenheit - 32) * 5/9

try:
    temperature = float(input("Enter the temperature value: "))
    unit = input("Is this temperature in Celsius (C) or Fahrenheit (F)? ").strip().upper()

    if unit == 'C':
        converted_temp = celsius_to_fahrenheit(temperature)
        print(f"{temperature}°C is equal to {converted_temp:.2f}°F")
    elif unit == 'F':
        converted_temp = fahrenheit_to_celsius(temperature)
        print(f"{temperature}°F is equal to {converted_temp:.2f}°C")
    else:
        print("Invalid unit entered. Please enter 'C' for Celsius or 'F' for Fahrenheit.")
except ValueError:
    print("Invalid temperature value. Please enter a numeric value.")
# Out:
# Enter the temperature value: 49.5
# Is this temperature in Celsius (C) or Fahrenheit (F)? c
# 49.5°C is equal to 121.10°F

# %%
#Write a simple calculator program that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.
def addition(a,b):
  return a+b
def subtraction(a,b):
  return a-b
def multiplication(a,b):
  return a*b
def division(a,b):
  return a/b

a=int(input('Enter the first number to perform operations: '))
b=int(input('Enter the second number to perform operations: '))
c=input('Choose the operations between +,-,*,/')

if c=='+':
  print(addition(a,b))
elif c=='-':
  print(subtraction(a,b))
elif c=='*':
  print(multiplication(a,b))
elif c=='/':
  print(division(a,b))
else:
  print('Please choose correct operation')
# Out:
# Enter the first number to perform operations: 5
# Enter the second number to perform operations: 5
# Choose the operations between +,-,*,/.
# Please choose correct operation

# %%
#Write a Python program for a simple "Guess the Number" game. Generate a random number, and have the user guess it.

import random

a=random.randint(1,100)

b=int(input('enter the number you guess: '))
if b>a:
  print('your guess is too high')
elif b<a:
  print('you guess is too low')
else:
  print(f'your guess is correct {a}')
# Out:
# 86
# enter the number you guess: 86
# your guess is correct 86

# %%
#Write a Python program that checks the strength of a user's password based on certain criteria.
import re

def check_password_strength(password):
    score = 0
    feedback = []

    # Criteria 1: Length
    if len(password) >= 8:
        score += 1
    else:
        feedback.append("Password should be at least 8 characters long.")

    # Criteria 2: Uppercase letters
    if re.search(r"[A-Z]", password):
        score += 1
    else:
        feedback.append("Password should contain at least one uppercase letter.")

    # Criteria 3: Lowercase letters
    if re.search(r"[a-z]", password):
        score += 1
    else:
        feedback.append("Password should contain at least one lowercase letter.")

    # Criteria 4: Digits
    if re.search(r"\d", password):
        score += 1
    else:
        feedback.append("Password should contain at least one digit.")

    # Criteria 5: Special characters
    if re.search(r"[!@#$%^&*()_+-=[]{};:'\"\\|,.<>/?`~]", password):
        score += 1
    else:
        feedback.append("Password should contain at least one special character (e.g., !@#$%).")

    print(f"\nPassword Strength Score: {score}/5")

    if score == 5:
        print("Strong password!")
    elif score >= 3:
        print("Moderate password.")
    else:
        print("Weak password.")

    if feedback:
        print("To improve your password strength:")
        for item in feedback:
            print(f"- {item}")

# Get user input for password
user_password = input("Enter your password to check its strength: ")
check_password_strength(user_password)
# Out:
# Enter your password to check its strength: murlig2003
#
# Password Strength Score: 3/5
# Moderate password.
# To improve your password strength:
# - Password should contain at least one uppercase letter.
# - Password should contain at least one special character (e.g., !@#$%).

# %%
#Write a Python program that calculates the final price of an item after applying a discount based on the purchase amount.

total_price=int(input())
discount=int(input())

after_price=total_price*(discount/100)

c=total_price-after_price

print(c)
# Out:
# 1000
# 10
# 900.0

# %%
#Write a Python program that simulates an ATM machine, allowing users to check their balance and withdraw money

# %%
#Write a Python program that greets the user differently based on the time of day.

from datetime import datetime

current_hour=datetime.now().hour

if current_hour < 12:
    greeting = "Good morning!"
elif 12 <= current_hour < 17:
    greeting = "Good afternoon!"
elif 17 <= current_hour < 21:
    greeting = "Good evening!"
else:
    greeting = "Good night!"



print(f'Welcome {greeting}')
# Out:
# Welcome Good morning!

# %%
#Write a Python program that calculates the final price of an item after applying a discount coupon code.
total_price=int(input())
coupon=input()
if coupon=='ABCDEF':
  discount=10
elif coupon=='GHIJK':
  discount=20
else:
  print('invalid coupon')

discounted_price=total_price*(discount/100)
print(discounted_price)
after_price=total_price-discounted_price
print(after_price)
# Out:
# 1000
# ABCDEF
# 100.0
# 900.0

# %%
# Write a Python program that calculates and prints the grade based on a given score, but also validates the input score.

total_score=int(input())

if total_score>=80:
  Grade='A'
elif total_score>=50 and total_score<80:
  Grade='B'
else:
  Grade='Fail'

print(Grade)
# Out:
# 80
# A

# %%
# Write a Python program that acts as a simple calculator and allows the user to choose the operation (addition, subtraction, multiplication, division).

# %%
#Write a Python program that determines the number of days in a given month.

def get_days_in_month(month, year):
    if month in [1, 3, 5, 7, 8, 10, 12]:
        return 31
    elif month in [4, 6, 9, 11]:
        return 30
    elif month == 2:
        if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
            return 29  # Leap year
        else:
            return 28
    else:
        return "Invalid month"

try:
    month_input = int(input("Enter the month number (1-12): "))
    year_input = int(input("Enter the year: "))

    days = get_days_in_month(month_input, year_input)

    if isinstance(days, int):
        print(f"There are {days} days in month {month_input} of {year_input}.")
    else:
        print(days)
except ValueError:
    print("Invalid input. Please enter valid numbers for month and year.")
# Out:
# Enter the month number (1-12): 7
# Enter the year: 2024
# There are 31 days in month 7 of 2024.

# %%
#Write a Python program that calculates a person's Body Mass Index (BMI) and categorizes it into different categories (underweight, normal weight, overweight, obese).

def calculate_bmi(weight_kg, height_m):
    if height_m <= 0:
        raise ValueError("Height cannot be zero or negative.")
    bmi = weight_kg / (height_m ** 2)
    return bmi

def categorize_bmi(bmi):
    if bmi < 18.5:
        return "Underweight"
    elif 18.5 <= bmi < 24.9:
        return "Normal weight"
    elif 25 <= bmi < 29.9:
        return "Overweight"
    else:
        return "Obese"

try:
    weight = float(input("Enter your weight in kilograms (kg): "))
    height = float(input("Enter your height in meters (m): "))

    if weight <= 0:
        print("Weight cannot be zero or negative.")
    else:
        bmi_value = calculate_bmi(weight, height)
        category = categorize_bmi(bmi_value)

        print(f"\nYour BMI is: {bmi_value:.2f}")
        print(f"Category: {category}")

except ValueError as e:
    print(f"Invalid input: {e}. Please ensure you enter numeric values for weight and height.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter your weight in kilograms (kg): 85
# Enter your height in meters (m): 160
#
# Your BMI is: 0.00
# Category: Underweight

# %% [markdown]
# ### Testing the BMI Calculator with Sample Values
#
# Below are some examples demonstrating the BMI calculation and categorization with predefined weight and height values. This bypasses the need for manual input.

# %%
# Test Case 1: Normal Weight
weight1 = 70  # kg
height1 = 1.75 # meters

try:
    bmi1 = calculate_bmi(weight1, height1)
    category1 = categorize_bmi(bmi1)
    print(f"Test Case 1 (Weight: {weight1}kg, Height: {height1}m):")
    print(f"  BMI: {bmi1:.2f}")
    print(f"  Category: {category1}\n")
except ValueError as e:
    print(f"Error in Test Case 1: {e}\n")
# Out:
# Test Case 1 (Weight: 70kg, Height: 1.75m):
#   BMI: 22.86
#   Category: Normal weight

# %%
# Test Case 2: Overweight
weight2 = 85  # kg
height2 = 1.70 # meters

try:
    bmi2 = calculate_bmi(weight2, height2)
    category2 = categorize_bmi(bmi2)
    print(f"Test Case 2 (Weight: {weight2}kg, Height: {height2}m):")
    print(f"  BMI: {bmi2:.2f}")
    print(f"  Category: {category2}\n")
except ValueError as e:
    print(f"Error in Test Case 2: {e}\n")

# %%
# Test Case 3: Underweight
weight3 = 50  # kg
height3 = 1.75 # meters

try:
    bmi3 = calculate_bmi(weight3, height3)
    category3 = categorize_bmi(bmi3)
    print(f"Test Case 3 (Weight: {weight3}kg, Height: {height3}m):")
    print(f"  BMI: {bmi3:.2f}")
    print(f"  Category: {category3}\n")
except ValueError as e:
    print(f"Error in Test Case 3: {e}\n")

# %%
# Test Case 4: Obese
weight4 = 100 # kg
height4 = 1.65 # meters

try:
    bmi4 = calculate_bmi(weight4, height4)
    category4 = categorize_bmi(bmi4)
    print(f"Test Case 4 (Weight: {weight4}kg, Height: {height4}m):")
    print(f"  BMI: {bmi4:.2f}")
    print(f"  Category: {category4}\n")
except ValueError as e:
    print(f"Error in Test Case 4: {e}\n")

# %%
# Test Case 5: Invalid Height (should raise ValueError)
weight5 = 70  # kg
height5 = 0    # meters

try:
    bmi5 = calculate_bmi(weight5, height5)
    category5 = categorize_bmi(bmi5)
    print(f"Test Case 5 (Weight: {weight5}kg, Height: {height5}m):")
    print(f"  BMI: {bmi5:.2f}")
    print(f"  Category: {category5}\n")
except ValueError as e:
    print(f"Error in Test Case 5: {e}\n")

# %%
#Write a Python program that converts letter grades (A, B, C, D, F) to their equivalent GPA values.
